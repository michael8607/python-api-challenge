# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
import geoviews as gv


# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 601

# %%
# The URL for the API to index variables in next step
test_url="http://api.openweathermap.org/data/2.5/weather?units=Imperial"
test_query_url=test_url+"&q="+'Hobart'+"&appid="+weather_api_key
test_weather=requests.get(test_query_url).json()
pprint(test_weather)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -42.8794, 'lon': 147.3294},
#  'dt': 1706671138,
#  'id': 2163355,
#  'main': {'feels_like': 68.05,
#           'humidity': 37,
#           'pressure': 1012,
#           'temp': 69.66,
#           'temp_max': 69.66,
#           'temp_min': 69.66},
#  'name': 'Hobart',
#  'sys': {'country': 'AU',
#          'id': 9545,
#          'sunrise': 1706641809,
#          'sunset': 1706693857,
#          'type': 1},
#  'timezone': 39600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 130, 'speed': 13.8}}

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(url+"&q="+city+"&appid="+weather_api_key+"&units=metric").json()# YOUR CODE HERE

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | codrington
# Processing Record 2 of Set 1 | zilair
# Processing Record 3 of Set 1 | ola
# Processing Record 4 of Set 1 | crane
# Processing Record 5 of Set 1 | siwa oasis
# Processing Record 6 of Set 1 | ilulissat
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | bayanhongor
# Processing Record 9 of Set 1 | sitka
# Processing Record 10 of Set 1 | edinburgh of the seven seas
# Processing Record 11 of Set 1 | hammerfest
# Processing Record 12 of Set 1 | lubang
# Processing Record 13 of Set 1 | margaret river
# Processing Record 14 of Set 1 | arno
# Processing Record 15 of Set 1 | touros
# Processing Record 16 of Set 1 | saksaul'skiy
# City not found. Skipping...
# Processing Record 17 of Set 1 | kiunga
# Processing Record 18 of Set 1 | acarau
# Processing Record 19 of Set 1 | papatowai
# Processing Record 20 of Set 1 | ust-nera
# Processing Record 21 of Set 1 | grytviken
# Processing Record 22 of Set 1 | bethel
# Processing Record 23 of Set 1 | ancud
# Processing Record 24 of Set 1 | tolanaro
# Processing Record 25 of Set 1 | hithadhoo
# Processing Record 26 of Set 1 | qaqortoq
# Processing Record 27 of Set 1 | puerto natales
# Processing Record 28 of Set 1 | waitangi
# Processing Record 29 of Set 1 | brentwood
# Processing Record 30 of Set 1 | atafu village
# Processing Record 31 of Set 1 | puerto ayora
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | barra de santo antonio
# Processing Record 34 of Set 1 | nantucket
# Processing Record 35 of Set 1 | jianshui
# Processing Record 36 of Set 1 | avarua
# Processing Record 37 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 38 of Set 1 | new amsterdam
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | port-aux-francais
# Processing Record 41 of Set 1 | akureyri
# Processing Record 42 of Set 1 | carutapera
# Processing Record 43 of Set 1 | beihai
# Processing Record 44 of Set 1 | saraykent
# Processing Record 45 of Set 1 | sakaiminato
# Processing Record 46 of Set 1 | christchurch
# Processing Record 47 of Set 1 | chulym
# Processing Record 48 of Set 1 | kruisfontein
# Processing Record 49 of Set 1 | port elizabeth
# Processing Record 50 of Set 1 | badger
# Processing Record 0 of Set 2 | porto novo
# Processing Record 1 of Set 2 | lorengau
# Processing Record 2 of Set 2 | shengli
# Processing Record 3 of Set 2 | dunedin
# Processing Record 4 of Set 2 | manokwari
# Processing Record 5 of Set 2 | banda aceh
# Processing Record 6 of Set 2 | college
# Processing Record 7 of Set 2 | belmonte
# Processing Record 8 of Set 2 | bikenibeu village
# Processing Record 9 of Set 2 | bilibino
# Processing Record 10 of Set 2 | thompson
# Processing Record 11 of Set 2 | wabag
# Processing Record 12 of Set 2 | anadyr
# Processing Record 13 of Set 2 | port saint john's
# Processing Record 14 of Set 2 | labrador city
# Processing Record 15 of Set 2 | wailua homesteads
# Processing Record 16 of Set 2 | east london
# Processing Record 17 of Set 2 | hawaiian paradise park
# Processing Record 18 of Set 2 | inza
# Processing Record 19 of Set 2 | sinabang
# Processing Record 20 of Set 2 | west island
# Processing Record 21 of Set 2 | tiksi
# Processing Record 22 of Set 2 | fortuna
# Processing Record 23 of Set 2 | gadzhiyevo
# Processing Record 24 of Set 2 | cairns city
# City not found. Skipping...
# Processing Record 25 of Set 2 | cockburn town
# Processing Record 26 of Set 2 | chateaulin
# Processing Record 27 of Set 2 | aasiaat
# Processing Record 28 of Set 2 | hamilton
# Processing Record 29 of Set 2 | olonkinbyen
# Processing Record 30 of Set 2 | ventspils
# Processing Record 31 of Set 2 | saipan
# Processing Record 32 of Set 2 | utrik
# Processing Record 33 of Set 2 | tataouine
# Processing Record 34 of Set 2 | longyearbyen
# Processing Record 35 of Set 2 | galesong
# Processing Record 36 of Set 2 | karatuzskoye
# Processing Record 37 of Set 2 | am djarass
# City not found. Skipping...
# Processing Record 38 of Set 2 | ust-tsilma
# Processing Record 39 of Set 2 | vorkuta
# Processing Record 40 of Set 2 | as sulayyil
# Processing Record 41 of Set 2 | adamstown
# Processing Record 42 of Set 2 | ribeira grande
# Processing Record 43 of Set 2 | vorgashor
# Processing Record 44 of Set 2 | yur'yevets
# Processing Record 45 of Set 2 | yokadouma
# Processing Record 46 of Set 2 | kodiak
# Processing Record 47 of Set 2 | stanley
# Processing Record 48 of Set 2 | bogande
# Processing Record 49 of Set 2 | abashiri
# Processing Record 0 of Set 3 | det udom
# Processing Record 1 of Set 3 | happy valley-goose bay
# Processing Record 2 of Set 3 | asadabad
# Processing Record 3 of Set 3 | saint cloud
# Processing Record 4 of Set 3 | mithi
# Processing Record 5 of Set 3 | usinsk
# Processing Record 6 of Set 3 | lerwick
# Processing Record 7 of Set 3 | challapata
# Processing Record 8 of Set 3 | tonota
# Processing Record 9 of Set 3 | ouro preto do oeste
# Processing Record 10 of Set 3 | invercargill
# Processing Record 11 of Set 3 | rongelap
# Processing Record 12 of Set 3 | talnakh
# Processing Record 13 of Set 3 | la palma
# Processing Record 14 of Set 3 | afaahiti
# Processing Record 15 of Set 3 | sartana
# Processing Record 16 of Set 3 | keflavik
# Processing Record 17 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 18 of Set 3 | turpan
# Processing Record 19 of Set 3 | puerto deseado
# Processing Record 20 of Set 3 | klaksvik
# Processing Record 21 of Set 3 | lebu
# Processing Record 22 of Set 3 | cidreira
# Processing Record 23 of Set 3 | namtsy
# Processing Record 24 of Set 3 | iqaluit
# Processing Record 25 of Set 3 | lucapa
# Processing Record 26 of Set 3 | chonchi
# Processing Record 27 of Set 3 | woolgoolga
# Processing Record 28 of Set 3 | hermanus
# Processing Record 29 of Set 3 | kavaratti
# Processing Record 30 of Set 3 | punta arenas
# Processing Record 31 of Set 3 | blackmans bay
# Processing Record 32 of Set 3 | maiwut
# City not found. Skipping...
# Processing Record 33 of Set 3 | isafjordur
# Processing Record 34 of Set 3 | san bernardo del viento
# Processing Record 35 of Set 3 | puerto armuelles
# Processing Record 36 of Set 3 | alice springs
# Processing Record 37 of Set 3 | coruripe
# Processing Record 38 of Set 3 | whitecourt
# Processing Record 39 of Set 3 | ryotsu-minato
# Processing Record 40 of Set 3 | lihue
# Processing Record 41 of Set 3 | udachny
# Processing Record 42 of Set 3 | new plymouth
# Processing Record 43 of Set 3 | susaki
# Processing Record 44 of Set 3 | fort bragg
# Processing Record 45 of Set 3 | bredasdorp
# Processing Record 46 of Set 3 | tura
# Processing Record 47 of Set 3 | dakoro
# Processing Record 48 of Set 3 | klyuchi
# Processing Record 49 of Set 3 | benguela
# Processing Record 0 of Set 4 | thyolo
# Processing Record 1 of Set 4 | vila velha
# Processing Record 2 of Set 4 | inhambane
# Processing Record 3 of Set 4 | murzuq
# Processing Record 4 of Set 4 | colonia
# Processing Record 5 of Set 4 | krasnozerskoye
# Processing Record 6 of Set 4 | ponnani
# Processing Record 7 of Set 4 | shimoda
# Processing Record 8 of Set 4 | margate
# Processing Record 9 of Set 4 | enewetak
# Processing Record 10 of Set 4 | whitefish
# Processing Record 11 of Set 4 | vadso
# Processing Record 12 of Set 4 | new norfolk
# Processing Record 13 of Set 4 | chinchani
# Processing Record 14 of Set 4 | mo i rana
# Processing Record 15 of Set 4 | port mathurin
# Processing Record 16 of Set 4 | blackwater
# Processing Record 17 of Set 4 | marat
# Processing Record 18 of Set 4 | katsuura
# Processing Record 19 of Set 4 | daye
# Processing Record 20 of Set 4 | sikasso
# Processing Record 21 of Set 4 | chegdomyn
# Processing Record 22 of Set 4 | miajadas
# Processing Record 23 of Set 4 | outapi
# City not found. Skipping...
# Processing Record 24 of Set 4 | melekeok village
# Processing Record 25 of Set 4 | anchorage
# Processing Record 26 of Set 4 | mossel bay
# Processing Record 27 of Set 4 | susuman
# Processing Record 28 of Set 4 | ulanhot
# Processing Record 29 of Set 4 | cat ba
# City not found. Skipping...
# Processing Record 30 of Set 4 | gobabis
# Processing Record 31 of Set 4 | kulhudhuffushi
# Processing Record 32 of Set 4 | wayne
# Processing Record 33 of Set 4 | kismayo
# Processing Record 34 of Set 4 | alenquer
# Processing Record 35 of Set 4 | kosh-agach
# Processing Record 36 of Set 4 | qarah bagh
# Processing Record 37 of Set 4 | puerto baquerizo moreno
# Processing Record 38 of Set 4 | semenov
# Processing Record 39 of Set 4 | waingapu
# Processing Record 40 of Set 4 | mukalla
# Processing Record 41 of Set 4 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 42 of Set 4 | uturoa
# Processing Record 43 of Set 4 | hadibu
# Processing Record 44 of Set 4 | papao
# Processing Record 45 of Set 4 | abepura
# Processing Record 46 of Set 4 | weno
# Processing Record 47 of Set 4 | ambovombe
# Processing Record 48 of Set 4 | isle of lewis
# City not found. Skipping...
# Processing Record 49 of Set 4 | sinazongwe
# Processing Record 0 of Set 5 | tornio
# Processing Record 1 of Set 5 | niquero
# Processing Record 2 of Set 5 | kodinsk
# Processing Record 3 of Set 5 | ujae
# Processing Record 4 of Set 5 | egilsstadir
# Processing Record 5 of Set 5 | tobol'sk
# Processing Record 6 of Set 5 | reggane
# Processing Record 7 of Set 5 | tommot
# Processing Record 8 of Set 5 | palangkaraya
# Processing Record 9 of Set 5 | tual
# Processing Record 10 of Set 5 | annau
# Processing Record 11 of Set 5 | malanje
# Processing Record 12 of Set 5 | mil'kovo
# Processing Record 13 of Set 5 | nemuro
# Processing Record 14 of Set 5 | castillos
# Processing Record 15 of Set 5 | manggar
# Processing Record 16 of Set 5 | polyarnyy
# Processing Record 17 of Set 5 | faya-largeau
# Processing Record 18 of Set 5 | les avirons
# Processing Record 19 of Set 5 | isangel
# Processing Record 20 of Set 5 | lokbatan
# Processing Record 21 of Set 5 | west wodonga
# Processing Record 22 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 23 of Set 5 | along
# Processing Record 24 of Set 5 | hiratacho
# Processing Record 25 of Set 5 | n'dalatando
# Processing Record 26 of Set 5 | weston
# Processing Record 27 of Set 5 | anna regina
# Processing Record 28 of Set 5 | kill devil hills
# Processing Record 29 of Set 5 | college station
# Processing Record 30 of Set 5 | senador jose porfirio
# Processing Record 31 of Set 5 | brookings
# Processing Record 32 of Set 5 | korla
# Processing Record 33 of Set 5 | selfoss
# Processing Record 34 of Set 5 | amga
# Processing Record 35 of Set 5 | pinheiro machado
# Processing Record 36 of Set 5 | carnarvon
# Processing Record 37 of Set 5 | georgetown
# Processing Record 38 of Set 5 | mokhsogollokh
# Processing Record 39 of Set 5 | chuguyevka
# Processing Record 40 of Set 5 | andapa
# Processing Record 41 of Set 5 | shakhtinsk
# Processing Record 42 of Set 5 | yarega
# Processing Record 43 of Set 5 | hasaki
# Processing Record 44 of Set 5 | tres arroyos
# Processing Record 45 of Set 5 | wynyard
# Processing Record 46 of Set 5 | trondheim
# Processing Record 47 of Set 5 | kawthoung
# City not found. Skipping...
# Processing Record 48 of Set 5 | yellowknife
# Processing Record 49 of Set 5 | brosteni
# Processing Record 0 of Set 6 | sierra vista
# Processing Record 1 of Set 6 | pokhvistnevo
# Processing Record 2 of Set 6 | portland
# Processing Record 3 of Set 6 | erriadh
# City not found. Skipping...
# Processing Record 4 of Set 6 | lazaro cardenas
# Processing Record 5 of Set 6 | paita
# Processing Record 6 of Set 6 | shiyan
# Processing Record 7 of Set 6 | grootfontein
# Processing Record 8 of Set 6 | nuuk
# Processing Record 9 of Set 6 | sungai penuh
# Processing Record 10 of Set 6 | berezovyy
# Processing Record 11 of Set 6 | ghat
# Processing Record 12 of Set 6 | khorixas
# Processing Record 13 of Set 6 | whitehorse
# Processing Record 14 of Set 6 | balabac
# Processing Record 15 of Set 6 | beni
# Processing Record 16 of Set 6 | sisimiut
# Processing Record 17 of Set 6 | cargados carajos
# City not found. Skipping...
# Processing Record 18 of Set 6 | la ronge
# Processing Record 19 of Set 6 | la passe
# Processing Record 20 of Set 6 | kuta
# Processing Record 21 of Set 6 | lebork
# Processing Record 22 of Set 6 | nieuw amsterdam
# Processing Record 23 of Set 6 | peniche
# Processing Record 24 of Set 6 | matoury
# Processing Record 25 of Set 6 | agadez
# Processing Record 26 of Set 6 | ertil'
# Processing Record 27 of Set 6 | ikovka
# Processing Record 28 of Set 6 | chui
# Processing Record 29 of Set 6 | fortaleza
# Processing Record 30 of Set 6 | miranda
# Processing Record 31 of Set 6 | haiku-pauwela
# Processing Record 32 of Set 6 | santiago
# Processing Record 33 of Set 6 | yverdon-les-bains
# Processing Record 34 of Set 6 | namibe
# Processing Record 35 of Set 6 | bonthe
# Processing Record 36 of Set 6 | la mira
# Processing Record 37 of Set 6 | aykhal
# Processing Record 38 of Set 6 | muroto-misakicho
# Processing Record 39 of Set 6 | masuguru
# Processing Record 40 of Set 6 | nambucca heads
# Processing Record 41 of Set 6 | argostolion
# Processing Record 42 of Set 6 | uthal
# Processing Record 43 of Set 6 | bayanaul
# Processing Record 44 of Set 6 | nasir
# Processing Record 45 of Set 6 | kerema
# Processing Record 46 of Set 6 | fuvahmulah
# City not found. Skipping...
# Processing Record 47 of Set 6 | kavalerovo
# Processing Record 48 of Set 6 | bohicon
# Processing Record 49 of Set 6 | roma
# Processing Record 0 of Set 7 | mount pleasant
# Processing Record 1 of Set 7 | vallenar
# Processing Record 2 of Set 7 | freeport
# Processing Record 3 of Set 7 | sagua la grande
# Processing Record 4 of Set 7 | kargasok
# Processing Record 5 of Set 7 | griffith
# Processing Record 6 of Set 7 | dubbo
# Processing Record 7 of Set 7 | yuzhno-kurilsk
# Processing Record 8 of Set 7 | nouadhibou
# Processing Record 9 of Set 7 | rustenburg
# Processing Record 10 of Set 7 | feijo
# Processing Record 11 of Set 7 | ust'-ilimsk
# Processing Record 12 of Set 7 | hami
# Processing Record 13 of Set 7 | qandala
# Processing Record 14 of Set 7 | antalaha
# Processing Record 15 of Set 7 | pacific grove
# Processing Record 16 of Set 7 | dudinka
# Processing Record 17 of Set 7 | brokopondo
# Processing Record 18 of Set 7 | high river
# Processing Record 19 of Set 7 | cable beach
# City not found. Skipping...
# Processing Record 20 of Set 7 | nerekhta
# Processing Record 21 of Set 7 | pangoa
# Processing Record 22 of Set 7 | kourou
# Processing Record 23 of Set 7 | dryden
# Processing Record 24 of Set 7 | mount pearl
# Processing Record 25 of Set 7 | lokot'
# Processing Record 26 of Set 7 | al kharijah
# Processing Record 27 of Set 7 | gizo
# Processing Record 28 of Set 7 | necochea
# Processing Record 29 of Set 7 | pechora
# Processing Record 30 of Set 7 | sereflikochisar
# Processing Record 31 of Set 7 | tchollire
# Processing Record 32 of Set 7 | tarinkot
# Processing Record 33 of Set 7 | fujin
# Processing Record 34 of Set 7 | east honolulu
# City not found. Skipping...
# Processing Record 35 of Set 7 | puerto colombia
# Processing Record 36 of Set 7 | hoxtolgay
# City not found. Skipping...
# Processing Record 37 of Set 7 | galle
# Processing Record 38 of Set 7 | port lincoln
# Processing Record 39 of Set 7 | borshchiv
# Processing Record 40 of Set 7 | laguna
# Processing Record 41 of Set 7 | san andres
# Processing Record 42 of Set 7 | isla vista
# Processing Record 43 of Set 7 | sotkamo
# Processing Record 44 of Set 7 | bay city
# Processing Record 45 of Set 7 | lautoka
# Processing Record 46 of Set 7 | mbanza-ngungu
# Processing Record 47 of Set 7 | manacapuru
# Processing Record 48 of Set 7 | atherton
# Processing Record 49 of Set 7 | nar'yan-mar
# Processing Record 0 of Set 8 | puerto madryn
# Processing Record 1 of Set 8 | chernomorskoye
# Processing Record 2 of Set 8 | sur
# Processing Record 3 of Set 8 | iskateley
# Processing Record 4 of Set 8 | kyaikkami
# Processing Record 5 of Set 8 | lincoln city
# Processing Record 6 of Set 8 | eastham
# Processing Record 7 of Set 8 | laojunmiao
# Processing Record 8 of Set 8 | pandan
# Processing Record 9 of Set 8 | edd
# Processing Record 10 of Set 8 | dondo
# Processing Record 11 of Set 8 | punta de bombon
# Processing Record 12 of Set 8 | tofol
# Processing Record 13 of Set 8 | santa vitoria
# Processing Record 14 of Set 8 | kudahuvadhoo
# Processing Record 15 of Set 8 | savannakhet
# Processing Record 16 of Set 8 | shakawe
# Processing Record 17 of Set 8 | geraldton
# Processing Record 18 of Set 8 | maceio
# Processing Record 19 of Set 8 | harrismith
# Processing Record 20 of Set 8 | myitkyina
# Processing Record 21 of Set 8 | petukhovo
# Processing Record 22 of Set 8 | valparaiso
# Processing Record 23 of Set 8 | umiray
# Processing Record 24 of Set 8 | bethlehem
# Processing Record 25 of Set 8 | tucuma
# Processing Record 26 of Set 8 | krnov
# Processing Record 27 of Set 8 | iquique
# Processing Record 28 of Set 8 | saldanha
# Processing Record 29 of Set 8 | barakani
# Processing Record 30 of Set 8 | okhotsk
# Processing Record 31 of Set 8 | kendari
# Processing Record 32 of Set 8 | hobyo
# Processing Record 33 of Set 8 | san patricio
# Processing Record 34 of Set 8 | pisco
# Processing Record 35 of Set 8 | kamaishi
# Processing Record 36 of Set 8 | moussoro
# Processing Record 37 of Set 8 | cheremukhovo
# Processing Record 38 of Set 8 | san juan
# Processing Record 39 of Set 8 | moengo
# Processing Record 40 of Set 8 | mana
# Processing Record 41 of Set 8 | antofagasta
# Processing Record 42 of Set 8 | viedma
# Processing Record 43 of Set 8 | bishkek
# Processing Record 44 of Set 8 | northam
# Processing Record 45 of Set 8 | villa yapacani
# Processing Record 46 of Set 8 | eydhafushi
# Processing Record 47 of Set 8 | isola di capo rizzuto
# Processing Record 48 of Set 8 | lompoc
# Processing Record 49 of Set 8 | tabou
# Processing Record 0 of Set 9 | tazovsky
# Processing Record 1 of Set 9 | progreso
# Processing Record 2 of Set 9 | tsiombe
# Processing Record 3 of Set 9 | callao
# Processing Record 4 of Set 9 | constantia
# Processing Record 5 of Set 9 | island harbour
# Processing Record 6 of Set 9 | dali
# Processing Record 7 of Set 9 | olivenza
# Processing Record 8 of Set 9 | el calafate
# Processing Record 9 of Set 9 | swift current
# Processing Record 10 of Set 9 | san antonio de pale
# Processing Record 11 of Set 9 | kerikeri
# Processing Record 12 of Set 9 | kuqa
# Processing Record 13 of Set 9 | hola
# Processing Record 14 of Set 9 | kokstad
# Processing Record 15 of Set 9 | vershino-darasunskiy
# Processing Record 16 of Set 9 | tranovaho
# City not found. Skipping...
# Processing Record 17 of Set 9 | baoshan
# Processing Record 18 of Set 9 | sol'tsy
# Processing Record 19 of Set 9 | tongchuanshi
# Processing Record 20 of Set 9 | biltine
# Processing Record 21 of Set 9 | tayu
# Processing Record 22 of Set 9 | inarajan village
# Processing Record 23 of Set 9 | joshimath
# Processing Record 24 of Set 9 | wenchang
# Processing Record 25 of Set 9 | novodvinsk
# Processing Record 26 of Set 9 | dombarovskiy
# Processing Record 27 of Set 9 | thunder bay
# Processing Record 28 of Set 9 | vilyuysk
# Processing Record 29 of Set 9 | tharad
# Processing Record 30 of Set 9 | jaru
# Processing Record 31 of Set 9 | severnoye
# Processing Record 32 of Set 9 | bargara
# City not found. Skipping...
# Processing Record 33 of Set 9 | creel
# Processing Record 34 of Set 9 | okha
# Processing Record 35 of Set 9 | 'ohonua
# City not found. Skipping...
# Processing Record 36 of Set 9 | seoni malwa
# Processing Record 37 of Set 9 | fontanelas
# Processing Record 38 of Set 9 | tshikapa
# Processing Record 39 of Set 9 | yeppoon
# Processing Record 40 of Set 9 | mogocha
# Processing Record 41 of Set 9 | peace river
# Processing Record 42 of Set 9 | magadan
# Processing Record 43 of Set 9 | tokar
# Processing Record 44 of Set 9 | kiomboi
# Processing Record 45 of Set 9 | sandnessjoen
# Processing Record 46 of Set 9 | karratha
# Processing Record 47 of Set 9 | chukhloma
# Processing Record 48 of Set 9 | mahdia
# Processing Record 49 of Set 9 | tarko-sale
# Processing Record 0 of Set 10 | kalabo
# Processing Record 1 of Set 10 | playas
# Processing Record 2 of Set 10 | suzhou
# Processing Record 3 of Set 10 | ouddorp
# Processing Record 4 of Set 10 | as salamiyah
# Processing Record 5 of Set 10 | fale old settlement
# Processing Record 6 of Set 10 | road town
# Processing Record 7 of Set 10 | sunagawa
# Processing Record 8 of Set 10 | sirte
# Processing Record 9 of Set 10 | kyzyl
# Processing Record 10 of Set 10 | kyren
# Processing Record 11 of Set 10 | barcelos
# Processing Record 12 of Set 10 | vingt cinq
# City not found. Skipping...
# Processing Record 13 of Set 10 | bel ombre
# Processing Record 14 of Set 10 | red hill
# Processing Record 15 of Set 10 | lake monticello
# Processing Record 16 of Set 10 | xai-xai
# Processing Record 17 of Set 10 | huatusco
# Processing Record 18 of Set 10 | tidjikja
# Processing Record 19 of Set 10 | dwarka
# Processing Record 20 of Set 10 | panama city beach
# Processing Record 21 of Set 10 | tenosique
# Processing Record 22 of Set 10 | bhind
# Processing Record 23 of Set 10 | benito juarez
# Processing Record 24 of Set 10 | suances
# Processing Record 25 of Set 10 | luanda
# Processing Record 26 of Set 10 | devinuwara
# City not found. Skipping...
# Processing Record 27 of Set 10 | gembu
# Processing Record 28 of Set 10 | palikir - national government center
# Processing Record 29 of Set 10 | dauphin
# Processing Record 30 of Set 10 | bikaner
# Processing Record 31 of Set 10 | zemio
# Processing Record 32 of Set 10 | techiman
# Processing Record 33 of Set 10 | nagqu
# Processing Record 34 of Set 10 | holly springs
# Processing Record 35 of Set 10 | najran
# Processing Record 36 of Set 10 | tafuna
# Processing Record 37 of Set 10 | alofi
# Processing Record 38 of Set 10 | newman
# Processing Record 39 of Set 10 | ahau
# City not found. Skipping...
# Processing Record 40 of Set 10 | dzuunmod
# Processing Record 41 of Set 10 | san ramon
# Processing Record 42 of Set 10 | yeonil
# Processing Record 43 of Set 10 | kapuskasing
# Processing Record 44 of Set 10 | costa teguise
# City not found. Skipping...
# Processing Record 45 of Set 10 | at taj
# Processing Record 46 of Set 10 | luderitz
# Processing Record 47 of Set 10 | ad darb
# Processing Record 48 of Set 10 | dulag
# Processing Record 49 of Set 10 | guanare
# Processing Record 0 of Set 11 | yamada
# Processing Record 1 of Set 11 | al manshah
# Processing Record 2 of Set 11 | kudymkar
# Processing Record 3 of Set 11 | queenstown
# Processing Record 4 of Set 11 | westport
# Processing Record 5 of Set 11 | kabompo
# Processing Record 6 of Set 11 | stromstad
# City not found. Skipping...
# Processing Record 7 of Set 11 | abra pampa
# Processing Record 8 of Set 11 | kichmengskiy gorodok
# Processing Record 9 of Set 11 | mount darwin
# Processing Record 10 of Set 11 | mineiros
# Processing Record 11 of Set 11 | richards bay
# Processing Record 12 of Set 11 | kolonia town
# Processing Record 13 of Set 11 | ngaoundere
# Processing Record 14 of Set 11 | remire-montjoly
# Processing Record 15 of Set 11 | kenora
# Processing Record 16 of Set 11 | val-d'or
# Processing Record 17 of Set 11 | saint-philippe
# Processing Record 18 of Set 11 | yefremov
# Processing Record 19 of Set 11 | huarmey
# Processing Record 20 of Set 11 | fort saskatchewan
# Processing Record 21 of Set 11 | retreat
# Processing Record 22 of Set 11 | luzilandia
# Processing Record 23 of Set 11 | daru
# Processing Record 24 of Set 11 | mili
# Processing Record 25 of Set 11 | imbituba
# Processing Record 26 of Set 11 | pospelikha
# Processing Record 27 of Set 11 | mondlo
# Processing Record 28 of Set 11 | la'ie
# Processing Record 29 of Set 11 | traverse city
# Processing Record 30 of Set 11 | buka
# Processing Record 31 of Set 11 | puerto aysen
# Processing Record 32 of Set 11 | razumnoye
# Processing Record 33 of Set 11 | nova vicosa
# Processing Record 34 of Set 11 | skowhegan
# Processing Record 35 of Set 11 | kayangel
# Processing Record 36 of Set 11 | fauske
# Processing Record 37 of Set 11 | kununurra
# Processing Record 38 of Set 11 | yelizovo
# Processing Record 39 of Set 11 | antsiranana
# Processing Record 40 of Set 11 | idfu
# Processing Record 41 of Set 11 | bejubang dua
# City not found. Skipping...
# Processing Record 42 of Set 11 | danielskuil
# Processing Record 43 of Set 11 | wanxian
# Processing Record 44 of Set 11 | broome
# Processing Record 45 of Set 11 | tromso
# Processing Record 46 of Set 11 | nyala
# Processing Record 47 of Set 11 | kotlas
# Processing Record 48 of Set 11 | rosarito
# Processing Record 49 of Set 11 | pipar
# Processing Record 0 of Set 12 | omarska
# Processing Record 1 of Set 12 | howrah
# Processing Record 2 of Set 12 | yelan'
# Processing Record 3 of Set 12 | malango
# Processing Record 4 of Set 12 | flying fish cove
# Processing Record 5 of Set 12 | siirt
# Processing Record 6 of Set 12 | liuhe
# Processing Record 7 of Set 12 | batesburg-leesville
# Processing Record 8 of Set 12 | buala
# Processing Record 9 of Set 12 | almeirim
# Processing Record 10 of Set 12 | ihosy
# Processing Record 11 of Set 12 | oroqen zizhiqi
# Processing Record 12 of Set 12 | colares
# Processing Record 13 of Set 12 | zalingei
# Processing Record 14 of Set 12 | galliano
# Processing Record 15 of Set 12 | palmer
# Processing Record 16 of Set 12 | mount gambier
# Processing Record 17 of Set 12 | basoko
# Processing Record 18 of Set 12 | borogontsy
# Processing Record 19 of Set 12 | kabare
# Processing Record 20 of Set 12 | rio gallegos
# Processing Record 21 of Set 12 | lospalos
# Processing Record 22 of Set 12 | tuensang
# Processing Record 23 of Set 12 | itaituba
# Processing Record 24 of Set 12 | emerald
# Processing Record 25 of Set 12 | aitape
# Processing Record 26 of Set 12 | bol'sherech'ye
# Processing Record 27 of Set 12 | talara
# Processing Record 28 of Set 12 | yuxi
# Processing Record 29 of Set 12 | ta`u
# Processing Record 30 of Set 12 | cangucu
# Processing Record 31 of Set 12 | kulia village
# City not found. Skipping...
# Processing Record 32 of Set 12 | abeche
# Processing Record 33 of Set 12 | cadale
# Processing Record 34 of Set 12 | ardakan
# Processing Record 35 of Set 12 | perevoz
# Processing Record 36 of Set 12 | chernyshevskiy
# Processing Record 37 of Set 12 | labin
# Processing Record 38 of Set 12 | gisborne
# Processing Record 39 of Set 12 | gamba
# Processing Record 40 of Set 12 | vilhena
# Processing Record 41 of Set 12 | beyneu
# Processing Record 42 of Set 12 | holualoa
# Processing Record 43 of Set 12 | abdanan
# Processing Record 44 of Set 12 | chop
# Processing Record 45 of Set 12 | blenheim
# Processing Record 46 of Set 12 | saint-pierre-d'oleron
# City not found. Skipping...
# Processing Record 47 of Set 12 | tinogasta
# Processing Record 48 of Set 12 | tutoia
# Processing Record 49 of Set 12 | novouzensk
# Processing Record 0 of Set 13 | fonadhoo
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)  

# Show Record Count
city_data_df.count()
# Out:
# City          572
# Lat           572
# Lng           572
# Max Temp      572
# Humidity      572
# Cloudiness    572
# Wind Speed    572
# Country       572
# Date          572
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  codrington -38.2667  141.9667     20.06        58          22        6.47
# 1      zilair  52.2332   57.4392     -9.24        95         100        4.21
# 2         ola  59.5833  151.2833    -21.37        82          14        1.99
# 3       crane  31.3974 -102.3501     14.92        38          38        3.37
# 4  siwa oasis  29.2041   25.5195      8.88        74          44        4.35
#
#   Country        Date
# 0      AU  1706671143
# 1      RU  1706671143
# 2      RU  1706671143
# 3      US  1706671144
# 4      EG  1706671144

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        codrington -38.2667  141.9667     20.06        58          22
# 1            zilair  52.2332   57.4392     -9.24        95         100
# 2               ola  59.5833  151.2833    -21.37        82          14
# 3             crane  31.3974 -102.3501     14.92        38          38
# 4        siwa oasis  29.2041   25.5195      8.88        74          44
#
#          Wind Speed Country        Date
# City_ID
# 0              6.47      AU  1706671143
# 1              4.21      RU  1706671143
# 2              1.99      RU  1706671143
# 3              3.37      US  1706671144
# 4              4.35      EG  1706671144

# %% [markdown]
# ## Latitude vs Temperature

# %%
#define your X & Y data
x_data = city_data_df['Lat']
y_data = city_data_df['Max Temp']

#plot the data
lat_vs_temp = plt.scatter(x_data, y_data, edgecolor = 'black')

#labels & grid
plt.grid(True)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.title('City Max Latitude vs. Temperature (2022-10-18)')
# Out:
# Text(0.5, 1.0, 'City Max Latitude vs. Temperature (2022-10-18)')

# %% [markdown]
# ## Latitude vs Humidity

# %%
#keep above x_data the same, change y_data to humidity
y_data = city_data_df['Humidity']

#plot the data as before
lat_vs_humid = plt.scatter(x_data, y_data, edgecolor = 'black')

#labels & grid
plt.grid(True)
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.title('City Latitude vs. Humidity (2022-10-18)')
# Out:
# Text(0.5, 1.0, 'City Latitude vs. Humidity (2022-10-18)')

# %% [markdown]
# ## Latitude vs Cloudiness

# %%
#keep above x_data the same, change y_data to cloudiness
y_data = city_data_df['Cloudiness']

#plot the data as before
lat_vs_humid = plt.scatter(x_data, y_data, edgecolor = 'black')

#labels & grid
plt.grid(True)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness  %')
plt.title('City Latitude vs. Cloudiness (2022-10-18)')
# Out:
# Text(0.5, 1.0, 'City Latitude vs. Cloudiness (2022-10-18)')

# %%
#keep above x_data the same, change y_data to wind speed
y_data = city_data_df['Wind Speed']

#plot the data as before
lat_vs_humid = plt.scatter(x_data, y_data, edgecolor = 'black')

#labels & grid
plt.grid(True)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title('City Latitude vs. Wind Speed (2022-10-18)')
# Out:
# Text(0.5, 1.0, 'City Latitude vs. Wind Speed (2022-10-18)')

# %%
# Define a function to create Linear Regression plots
def regression_plot(x_values, y_values, x_label, y_label, title):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values, edgecolor = 'black')
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    plt.legend()
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1            zilair  52.2332   57.4392     -9.24        95         100
# 2               ola  59.5833  151.2833    -21.37        82          14
# 3             crane  31.3974 -102.3501     14.92        38          38
# 4        siwa oasis  29.2041   25.5195      8.88        74          44
# 5         ilulissat  69.2167  -51.1000    -22.99        45          21
#
#          Wind Speed Country        Date
# City_ID
# 1              4.21      RU  1706671143
# 2              1.99      RU  1706671143
# 3              3.37      US  1706671144
# 4              4.35      EG  1706671144
# 5              2.06      GL  1706671144

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                         codrington -38.2667  141.9667     20.06        58
# 9        edinburgh of the seven seas -37.0676  -12.3116     13.86        57
# 12                    margaret river -33.9500  115.0667     28.05        49
# 14                            touros  -5.1989  -35.4608     27.16        72
# 15                            kiunga  -6.1219  141.2906     30.85        63
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                22        6.47      AU  1706671143
# 9                81        0.80      SH  1706671145
# 12                0        4.02      AU  1706671146
# 14               13        5.32      BR  1706671077
# 15               97        1.69      PG  1706671147

# %%
# northern hemispher latitude vs temp
regression_plot(northern_hemi_df['Lat'], 
        northern_hemi_df['Max Temp'],
        x_label = 'Latitude',
        y_label = 'Max Temp',
        title = 'Northern Hemisphere')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#southern hemisphere Latitude vs Temp
regression_plot(southern_hemi_df['Lat'], 
        southern_hemi_df['Max Temp'],
        x_label = 'Latitude',
        y_label = 'Max Temp',
        title = 'Southern Hemisphere')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#northern hemisphere Latitude vs humidity
regression_plot(southern_hemi_df['Lat'], 
        southern_hemi_df['Humidity'],
        x_label = 'Latitude',
        y_label = 'Humidity',
        title = 'Southern Hemisphere')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#southern hemisphere Latitude vs humidity
regression_plot(southern_hemi_df['Lat'], 
        southern_hemi_df['Humidity'],
        x_label = 'Latitude',
        y_label = 'Humidity',
        title = 'Southern Hemisphere')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Cloudiness vs Latitude Linear Regression Plot

# %%
#northern hemisphere Latitude vs Cloudiness
regression_plot(northern_hemi_df['Lat'], 
        northern_hemi_df['Cloudiness'],
        x_label = 'Latitude',
        y_label = 'Cloudiness',
        title = 'Northern Hemisphere')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#southern hemisphere Latitude vs Temp
regression_plot(southern_hemi_df['Lat'], 
        southern_hemi_df['Cloudiness'],
        x_label = 'Latitude',
        y_label = 'Cloudiness',
        title = 'Southern Hemisphere')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Wind Speed vs Latitude Linear regression

# %%
#northern hemisphere Latitude vs Temp
regression_plot(northern_hemi_df['Lat'], 
        northern_hemi_df['Wind Speed'],
        x_label = 'Latitude',
        y_label = 'Wind Speed',
        title = 'Northern Hemisphere')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#southern hemisphere Latitude vs Temp
regression_plot(southern_hemi_df['Lat'], 
        southern_hemi_df['Wind Speed'],
        x_label = 'Latitude',
        y_label = 'Wind Speed',
        title = 'Southern Hemisphere')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
